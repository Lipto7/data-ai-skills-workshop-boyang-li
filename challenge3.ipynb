# %%
# %%bash
# PROJECT_ID=$(gcloud config get-value project)
# DATASET="challenge3"
#
# bq --location=US mk -d \
#     --description "emergency calls response times" \
#     "${PROJECT_ID}:${DATASET}" || true
# Out:
# Dataset 'qwiklabs-gcp-00-46c4d2064c57:challenge3' successfully created.

# %%
import os
PROJECT_ID = "qwiklabs-gcp-00-46c4d2064c57"
DATASET = "challenge3"
os.environ['PROJECT_ID'] = PROJECT_ID
os.environ['DATASET'] = DATASET

# %%
# !bq load \
  --source_format=CSV \
  --skip_leading_rows=1 \
  --autodetect \
  $PROJECT_ID:$DATASET.weather_data_raw \
  gs://labs.roitraining.com/data-to-ai-workshop/weather_data.csv
# Out:
# Waiting on bqjob_r248dee365219e3fb_0000019bc2fd951f_1 ... (1s) Current status: DONE

# %%
#gemini-external-model
import subprocess, json, re

LOCATION = "US"
CONNECTION_ID = "gemini_conn"

# Create the connection
subprocess.run([
    "bq", f"--project_id={PROJECT_ID}", "mk", "--connection",
    f"--location={LOCATION}",
    "--connection_type=CLOUD_RESOURCE",
    CONNECTION_ID
], check=False)

# Show the connection and extract the service account
out = subprocess.check_output([
    "bq", f"--project_id={PROJECT_ID}", "show", "--format=prettyjson",
    "--connection", f"{PROJECT_ID}.{LOCATION}.{CONNECTION_ID}"
], text=True)

conn = json.loads(out)
sa = conn["cloudResource"]["serviceAccountId"]
print("Connection service account:", sa)
# Out:
# Connection service account: bqcx-398662785422-l0et@gcp-sa-bigquery-condel.iam.gserviceaccount.com

# %%
# Grant Vertex AI User role to the connection service account
subprocess.check_call([
    "gcloud", "projects", "add-iam-policy-binding", PROJECT_ID,
    "--member", f"serviceAccount:{sa}",
    "--role", "roles/aiplatform.user"
])

print("Granted roles/aiplatform.user to:", sa)
# Out:
# Granted roles/aiplatform.user to: bqcx-398662785422-l0et@gcp-sa-bigquery-condel.iam.gserviceaccount.com

# %%
#gemini model
from google.cloud import bigquery
client = bigquery.Client(project=PROJECT_ID)

DATASET = "challenge3"
MODEL_NAME = f"{PROJECT_ID}.{DATASET}.gemini_model"
CONN_REF = f"{LOCATION}.{CONNECTION_ID}"

create_model_sql = f"""
CREATE OR REPLACE MODEL `{MODEL_NAME}`
REMOTE WITH CONNECTION `{CONN_REF}`
OPTIONS (
  ENDPOINT = 'gemini-2.5-flash'
)
"""
client.query(create_model_sql).result()
print("Created remote model:", MODEL_NAME)
# Out:
# Created remote model: qwiklabs-gcp-00-46c4d2064c57.challenge3.gemini_model

# %%
#generate report
WEATHER_TABLE = f"{PROJECT_ID}.{DATASET}.weather_data_raw"
OUT_TABLE = f"{PROJECT_ID}.{DATASET}.weather_data_with_report" # create a new table to store
MODEL_NAME = f"{PROJECT_ID}.{DATASET}.gemini_model"

sql = f"""
CREATE OR REPLACE TABLE `{OUT_TABLE}` AS
SELECT
  JSON_VALUE(ml_generate_text_result, '$.candidates[0].content.parts[0].text') AS weather_report,
  * EXCEPT(prompt, ml_generate_text_result, ml_generate_text_status)
FROM ML.GENERATE_TEXT(
  MODEL `{MODEL_NAME}`,
  (
    SELECT
      CONCAT(
        'Create a short weather report (2-4 sentences) and any warnings if needed based on this record: ',
        TO_JSON_STRING(t)
      ) AS prompt,
      t.*
    FROM `{WEATHER_TABLE}` AS t
  ),
  STRUCT(0.2 AS temperature, 2000 AS max_output_tokens)
);
"""
client.query(sql).result()
print("Report created, output is written to:", OUT_TABLE)
# Out:
# Report created, output is written to: qwiklabs-gcp-00-46c4d2064c57.challenge3.weather_data_with_report

# %%
#display table output for grading
q1 = f"""
SELECT *
FROM `{PROJECT_ID}.{DATASET}.weather_data_with_report`
limit 20
"""
df_display = client.query(q1).to_dataframe()
df_display
# Out:
#                                        weather_report        date     city  \
# 0   Good morning, Atlanta! On March 10, 2025, expe...  2025-03-10  Atlanta
# 1   Good morning, Atlanta! On March 14, 2025, expe...  2025-03-14  Atlanta
# 2   Good morning, Atlanta! On March 1st, expect cl...  2025-03-01  Atlanta
# 3   Good morning, Atlanta! On March 5, 2025, expec...  2025-03-05  Atlanta
# 4   Atlanta, GA is experiencing a warm and cloudy ...  2025-02-26  Atlanta
# 5   Good morning, Atlanta! On February 21, 2025, e...  2025-02-21  Atlanta
# 6   Good morning, Boston! On February 19, 2025, ex...  2025-02-19   Boston
# 7   Good morning, Boston! On Thursday, March 13, 2...  2025-03-13   Boston
# 8   Good morning, Boston! Today, March 19, 2025, e...  2025-03-19   Boston
# 9   Good morning, Boston! On March 9, 2025, expect...  2025-03-09   Boston
# 10  In Chicago, IL on February 27, 2025, expect a ...  2025-02-27  Chicago
# 11  Good morning, Chicago! On February 25th, expec...  2025-02-25  Chicago
# 12  Good morning, Chicago! On February 23, 2025, e...  2025-02-23  Chicago
# 13  Good morning, Chicago! On February 19, 2025, e...  2025-02-19  Chicago
# 14  In Chicago, IL on March 3, 2025, expect cloudy...  2025-03-03  Chicago
# 15  Good morning, Denver! On Monday, February 24th...  2025-02-24   Denver
# 16  Good morning, Denver! On March 15, 2025, expec...  2025-03-15   Denver
# 17  For Denver, CO on February 27, 2025, expect a ...  2025-02-27   Denver
# 18  Good morning, Denver! On March 17, 2025, expec...  2025-03-17   Denver
# 19  Good morning, Denver! On March 9, 2025, expect...  2025-03-09   Denver
#
#    state  temperature_f  wind_speed_mph  precipitation_in  \
# 0     GA           59.5             9.6              0.09
# 1     GA           71.7             7.2              0.18
# 2     GA           51.7             4.7              0.08
# 3     GA           74.4             5.1              0.02
# 4     GA           75.2            10.4              0.03
# 5     GA           55.7             5.0              0.12
# 6     MA           61.7             3.9              0.11
# 7     MA           71.9             9.8              0.16
# 8     MA           60.7             6.4              0.04
# 9     MA           76.7             4.3              0.09
# 10    IL           53.2             5.4              0.06
# 11    IL           65.8            10.1              0.01
# 12    IL           57.3             3.3              0.09
# 13    IL           63.8             9.5              0.10
# 14    IL           71.6            10.6              0.12
# 15    CO           74.1             4.2              0.13
# 16    CO           59.5            11.1              0.16
# 17    CO           57.8             7.5              0.14
# 18    CO           51.4             7.9              0.04
# 19    CO           62.4             3.5              0.04
#
#     barometric_pressure_inHg  humidity_percent weather_condition
# 0                      29.67              57.2            Cloudy
# 1                      29.92              55.3            Cloudy
# 2                      29.74              49.9            Cloudy
# 3                      29.92              50.4            Cloudy
# 4                      29.58              49.9            Cloudy
# 5                      29.80              50.4            Cloudy
# 6                      29.62              54.1            Cloudy
# 7                      29.99              42.3            Cloudy
# 8                      29.83              49.4            Cloudy
# 9                      29.52              40.9            Cloudy
# 10                     29.76              51.7            Cloudy
# 11                     29.50              54.2            Cloudy
# 12                     29.70              40.6            Cloudy
# 13                     29.60              56.6            Cloudy
# 14                     29.54              53.9            Cloudy
# 15                     29.53              43.8            Cloudy
# 16                     29.68              57.7            Cloudy
# 17                     29.58              53.2            Cloudy
# 18                     29.54              53.8            Cloudy
# 19                     29.78              49.4            Cloudy
